# %%
# !python -m optimum.exporters.onnx --model arsapkota/nepali-sentiment-bert-regu2.o nepali-bert-onnx22.o-export
# Out:
# 2025-11-23 09:44:55.209823: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763891095.234991   25487 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763891095.242472   25487 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763891095.261644   25487 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
from google.colab import files
import os

ONNX_FILE_PATH = "./nepali-bert-onnx22.o-export"

if os.path.exists(ONNX_FILE_PATH):
    print(f"Downloading {ONNX_FILE_PATH}...")
    files.download(ONNX_FILE_PATH)
else:
    print(f"File not found at {ONNX_FILE_PATH}. Please make sure the export step ran correctly.")
